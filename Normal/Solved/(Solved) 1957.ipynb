# %%
s = "leeetcode"
s = "aaabaaaa"
s = "aab"
s = "a"
s = "aa"
s = "aaa"
s = "aaaa"
s = "..."

# %%
letters = 'abcdefghijklmnopqrstuvwxyz'
letters = [x for x in letters]
nono = [3*x for x in letters]
while any(sub in s for sub in nono):
    for l in letters:
        s = s.replace(3*l,2*l)
print(s)
# Out:
# ...
